# %%
import tweepy
from textblob import TextBlob
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import style

# %%
consumer_key = 'qKhoRN2cSVZt7H8sguZnyigaB'
cosumer_secret = '5Ue8LmdUg7pRG3nXVYl0zKR7fpFzaxbFjRi6zSAiLA4QZktBvC'

access_token = '91344333-YPxzWWsvltstTLIIa9RDSAzqSWCbpXrGKQn0GPAws'
access_token_secret = 'dHZv8k20mDZECdLlfMXVqffJWuhLPPupNOrVSmwD3jk7U'

auth = tweepy.OAuthHandler(consumer_key, cosumer_secret)
auth.set_access_token(access_token,access_token_secret)

api = tweepy.API(auth)

style.use("ggplot")

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

public_tweets = api.search('Climate Change')

xar = []
yar = []
yar1 = []
x = 0
y = 0
for tweets in public_tweets:
    print(tweets.text)
    analysis = TextBlob(tweets.text)
    print(analysis.sentiment)
    polarity = analysis.sentiment[0]
    subjectivity = analysis.sentiment[1]
    x+=1
    xar.append(x)
    yar.append(polarity)
    yar1.append(subjectivity)

    
ax1.clear
ax1.plot(xar,yar,color = 'olive',label="polarity")
ax1.plot(xar,yar1,color = 'cyan',label="subjectivity")
plt.legend()
plt.show()
# Out:
# RT @tylerwhat16: Ontario’s auditor general found that Doug Ford’s Conservatives (terrible) plan to reduce carbon emissions “is not supporte…
# Sentiment(polarity=-0.475, subjectivity=0.75)
# RT @GeraldKutney: Why do I bother with climate deniers? I am NOT trying to change them; I am trying to discredit them. Their influence must…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @AwelAmanTawe: Great to be at #SEUKAwards with @WalesCoOpCentre listening to @AndyBurnhamGM . Think we’re the only ones here tonight wit…
# Sentiment(polarity=0.4, subjectivity=0.875)
# RT @HuffPostPol: Global carbon emissions will hit a record high in 2019 once again, despite calls for dramatic action on climate change. ht…
# Sentiment(polarity=-0.04333333333333333, subjectivity=0.31)
# RT @RoKhanna: The blackouts and wildfires in California are what happens when disinvestment in infrastructure meets the disastrous effects…
# Sentiment(polarity=-0.7, subjectivity=0.8)
# ...
